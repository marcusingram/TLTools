# %%
# %matplotlib inline
from CUETools import CUETools
import scipy.io as sio

FMC_file = 'TestData.mat'
FMC = sio.loadmat(FMC_file)
FMC_dataset =  FMC['FMC'].T
ProbeElementLocations = FMC['Array']
TStart = FMC['FMCTimeStart']

TFM = CUETools.PyTFM()

# %%
TFM.uploadFMC(FMC_dataset)
TFM.uploadProbe(ProbeElementLocations)
TFM.setParameters(Velocity1=5790,Fs=72792400,Ts=TStart)
TFM.setRefraction(RefractionType='flat',Velocity2=1496)
TFM.raiseArrayToHeight(11e-3)
TFM.setImage(y0=-20e-3,ny=1024,y1=20e-3,z0=0,nz=1024,z1=-30e-3)

# %%
TFM.printTFM()
TFM.printGPUstats()
# Out:
# Global memory occupancy:83.36% free
# Gridsize is currently set to 8192 for a 1D configuration with a blocksize of 128
