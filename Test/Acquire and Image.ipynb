# %%
# %matplotlib inline
from TLTools import Imaging
from TLTools import Acquisition
from IPython.display import clear_output
import scipy.io as sio

DSL = Acquisition.DSL()
TFM = Imaging.PyTFM()

# %%
while True:
    FMC = DSL.acquire_single_FMC()
    TFM.TLuploadFMC(FMC)
    TFM.buildProbe(0.7e-3)
    TFM.setParameters(Velocity1=5790)
    TFM.setRefraction(RefractionType='None')
    TFM.raiseArrayToHeight(0)
    TFM.setImage(y0=-20e-3,ny=1024,y1=20e-3,z0=0,nz=1024,z1=-100e-3)
    TFM.printTFM()
# Out:
# TFM took 0.867 seconds
# C:\ProgramData\Anaconda3\lib\site-packages\TLTools\Imaging.py:293: RuntimeWarning: divide by zero encountered in log10
#   self.TFM_log = 20*np.log10(TFM2)
# TFM took 0.867 seconds
# TFM took 0.865 seconds
# TFM took 0.866 seconds
# TFM took 0.866 seconds
# TFM took 0.866 seconds
# TFM took 0.866 seconds
# TFM took 0.866 seconds
# TFM took 0.867 seconds
# TFM took 0.867 seconds
# TFM took 0.866 seconds
# TFM took 0.92 seconds
# TFM took 0.867 seconds
# TFM took 0.866 seconds
# TFM took 0.867 seconds
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\TLTools\Imaging.py in processImage(self)
#     287             try:
# --> 288                 self.doImage()
#     289             except:
#
# C:\ProgramData\Anaconda3\lib\site-packages\TLTools\Imaging.py in doImage(self)
#     277         t = time.time()
# --> 278         TFM_coeff(cuda.Out(self.TFM_image), cuda.In(self.FMC), cuda.In(self.ArrayGPU), self.n_elem, self.Fs, cuda.In(self.z), self.nz, self.sample_length, self.Ts, self.Coeff_gpu,block=(self.blockSize,1,1), grid=(self.gridSize,1))
#     279         elapsed = time.time() - t
#
# C:\ProgramData\Anaconda3\lib\site-packages\pycuda\driver.py in function_call(func, *args, **kwargs)
#     404             if post_handlers or time_kernel:
# --> 405                 Context.synchronize()
#     406
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# Exception                                 Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\TLTools\Imaging.py in printTFM(self, **kwargs)
#     313                 try:
# --> 314                     self.processImage()
#     315                 except:
#
# C:\ProgramData\Anaconda3\lib\site-packages\TLTools\Imaging.py in processImage(self)
#     289             except:
# --> 290                 raise Exception('The TFM image could not be generated at this time')
#     291         TFM2 = self.TFM_lin / max(self.TFM_lin.flatten())
#
# Exception: The TFM image could not be generated at this time
#
# During handling of the above exception, another exception occurred:
#
# Exception                                 Traceback (most recent call last)
# <ipython-input-3-ccb4a22f7be8> in <module>()
#       7     TFM.raiseArrayToHeight(0)
#       8     TFM.setImage(y0=-20e-3,ny=1024,y1=20e-3,z0=0,nz=1024,z1=-100e-3)
# ----> 9     TFM.printTFM()
#      10
#
# C:\ProgramData\Anaconda3\lib\site-packages\TLTools\Imaging.py in printTFM(self, **kwargs)
#     314                     self.processImage()
#     315                 except:
# --> 316                     raise Exception('Couldn''t produce a logarithmic TFM image')
#     317             plt.imshow(self.TFM_log,extent=(min(self.y),max(self.y),min(self.z),max(self.z)),cmap=parula.parula_map)
#     318             plt.clim(-dyrange,0)
#
# Exception: Couldnt produce a logarithmic TFM image
